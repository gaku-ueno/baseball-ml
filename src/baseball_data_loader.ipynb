# %% [markdown]
# # Code to prepare datasets for analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from pybaseball import batting_stats
from pybaseball import statcast_batter_expected_stats, statcast_batter_exitvelo_barrels

# %%
qualifying_threshold = 100

fg_bat_data = batting_stats(2015, 2024, qual = qualifying_threshold)
fg_bat_data
# Out:
#        IDfg  Season            Name   Team  Age    G   AB   PA    H   1B  ...  \
# 1     15640    2024     Aaron Judge    NYY   32  158  559  704  180   85  ...
# 4     15640    2022     Aaron Judge    NYY   30  157  570  696  177   87  ...
# 71    25764    2024  Bobby Witt Jr.    KCR   24  161  636  709  211  123  ...
# 7     13611    2018    Mookie Betts    BOS   25  136  520  614  180   96  ...
# 9     10155    2018      Mike Trout    LAA   26  140  471  608  147   80  ...
# ...     ...     ...             ...    ...  ...  ...  ...  ...  ...  ...  ...
# 3942   3179    2016  Dioner Navarro  - - -   32  101  304  334   63   42  ...
# 4236  12155    2024   Eddie Rosario  - - -   32   91  297  319   52   30  ...
# 4360   3448    2019     Jeff Mathis    TEX   36   88  228  244   36   25  ...
# 4308  11615    2024   Brandon Drury    LAA   31   97  325  360   55   44  ...
# 4184   9272    2018     Chris Davis    BAL   32  128  470  522   79   51  ...
#
#       maxEV  HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  L-WAR
# 1     117.5      238     0.609     391  0.146  0.267  NaN   NaN    NaN   11.3
# 4     118.4      246     0.609     404  0.169  0.287  NaN   NaN    NaN   11.4
# 71    116.9      259     0.481     538  0.138  0.236  NaN   NaN    NaN   10.0
# 7     110.6      217     0.500     434  0.220  0.270  NaN   NaN    NaN   10.4
# 9     118.0      162     0.460     352  0.201  0.261  NaN   NaN    NaN    9.5
# ...     ...      ...       ...     ...    ...    ...  ...   ...    ...    ...
# 3942  104.3       52     0.218     238  0.187  0.287  NaN   NaN    NaN   -1.8
# 4236  110.2       96     0.425     226  0.146  0.281  NaN   NaN    NaN   -2.3
# 4360  105.5       37     0.261     142  0.155  0.322  NaN   NaN    NaN   -2.1
# 4308  113.7       87     0.352     247  0.175  0.280  NaN   NaN    NaN   -1.9
# 4184  111.8      113     0.401     282  0.174  0.316  NaN   NaN    NaN   -2.6
#
# [4375 rows x 320 columns]

# %%
fg_bat_data.to_csv('../data/fangraphs_player_data.csv', index = False)
