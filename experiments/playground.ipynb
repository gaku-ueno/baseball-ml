# %% [markdown]
# # Playground
# - A place to put random bits of code and see how they work.

# %%
import pandas as pd
import numpy as np

# %%
from pybaseball import statcast_batter
from pybaseball import playerid_lookup

shohei_id = playerid_lookup('ohtani', 'shohei')
# Out:
# Gathering player lookup table. This may take a moment.

# %%
shohei_id
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0    ohtani     shohei     660271  ohtas001  ohtansh01          19755
#
#    mlb_played_first  mlb_played_last
# 0            2018.0           2024.0

# %%
statcast_batter('2024-04-01', '2024-09-10', player_id = 660271)
# Out:
# Gathering Player Data
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            ST  2024-09-10           82.6           2.90           5.30
# 1            ST  2024-09-10           83.7           2.99           5.18
# 2            ST  2024-09-10           82.1           3.03           5.17
# 3            FS  2024-09-10           83.2           3.02           5.31
# 4            ST  2024-09-10           82.6           3.06           5.20
# ...         ...         ...            ...            ...            ...
# 2430         FS  2024-04-01           90.7          -1.50           5.97
# 2431         FC  2024-04-01           87.5          -1.88           6.11
# 2432         FF  2024-04-01           94.0          -1.76           6.12
# 2433         FF  2024-04-01           97.8          -1.24           6.20
# 2434         FC  2024-04-01           84.9          -1.73           6.10
#
#          player_name  batter  pitcher                     events  \
# ...

# %%
from pybaseball import batting_stats

bat_stat = batting_stats(2021, 2024, qual = 502, split_seasons = True)
bat_stat
# Out:
#       IDfg  Season               Name   Team  Age    G   AB   PA    H   1B  \
# 0    15640    2024        Aaron Judge    NYY   32  158  559  704  180   85
# 1    15640    2022        Aaron Judge    NYY   30  157  570  696  177   87
# 15   25764    2024     Bobby Witt Jr.    KCR   24  161  636  709  211  123
# 4    19755    2024      Shohei Ohtani    LAD   29  159  636  731  197   98
# 5    18401    2023   Ronald Acuna Jr.    ATL   25  159  643  735  217  137
# ..     ...     ...                ...    ...  ...  ...  ...  ...  ...  ...
# 477  17982    2024          Ty France  - - -   29  140  479  535  112   75
# 510  21897    2024  Christopher Morel  - - -   25  152  535  611  105   70
# 507  10472    2023  Enrique Hernandez  - - -   31  140  465  508  110   76
# 505  19600    2024   Bryan De La Cruz  - - -   27  149  584  622  136   90
# 453  10815    2023   Jurickson Profar  - - -   30  125  459  521  111   73
#
# ...

# %%
for i in range(len(bat_stat.columns)):
    print(bat_stat.columns[i])
# Out:
# IDfg
# Season
# Name
# Team
# Age
# G
# AB
# PA
# H
# 1B
# 2B
# 3B
# HR
# R
# RBI
# BB
# IBB
# SO
# HBP
# SF
# SH
# GDP
# SB
# CS
# AVG
# GB
# FB
# LD
# IFFB
# Pitches
# Balls
# Strikes
# IFH
# BU
# BUH
# BB%
# K%
# BB/K
# OBP
# SLG
# OPS
# ISO
# BABIP
# GB/FB
# LD%
# GB%
# FB%
# IFFB%
# HR/FB
# IFH%
# BUH%
# wOBA
# wRAA
# wRC
# Bat
# Fld
# Rep
# Pos
# RAR
# WAR
# Dol
# Spd
# wRC+
# WPA
# -WPA
# +WPA
# RE24
# REW
# pLI
# phLI
# PH
# WPA/LI
# Clutch
# FB% (Pitch)
# FBv
# SL%
# SLv
# CT%
# CTv
# CB%
# CBv
# CH%
# CHv
# SF%
# SFv
# KN%
# KNv
# XX%
# PO%
# wFB
# wSL
# wCT
# wCB
# wCH
# wSF
# wKN
# wFB/C
# wSL/C
# wCT/C
# wCB/C
# wCH/C
# wSF/C
# wKN/C
# O-Swing%
# Z-Swing%
# Swing%
# O-Contact%
# Z-Contact%
# Contact%
# Zone%
# F-Strike%
# SwStr%
# BsR
# FA% (sc)
# FT% (sc)
# FC% (sc)
# FS% (sc)
# FO% (sc)
# SI% (sc)
# SL% (sc)
# CU% (sc)
# KC% (sc)
# EP% (sc)
# CH% (sc)
# SC% (sc)
# KN% (sc)
# UN% (sc)
# vFA (sc)
# vFT (sc)
# vFC (sc)
# vFS (sc)
# vFO (sc)
# vSI (sc)
# vSL (sc)
# ...

# %%
batting_stats(2000, 2024)
# Out:
#        IDfg  Season                 Name   Team  Age    G   AB   PA    H   1B  \
# 0      1109    2002          Barry Bonds    SFG   37  143  403  612  149   70
# 2      1109    2001          Barry Bonds    SFG   36  153  476  664  156   49
# 1      1109    2004          Barry Bonds    SFG   39  147  373  617  135   60
# 7     15640    2024          Aaron Judge    NYY   32  158  559  704  180   85
# 18    15640    2022          Aaron Judge    NYY   30  157  570  696  177   87
# ...     ...     ...                  ...    ...  ...  ...  ...  ...  ...  ...
# 3262   1213    2009          Aubrey Huff  - - -   32  150  536  597  129   83
# 3196    857    2005      Bernie Williams    NYY   36  141  485  546  121   89
# 3622   8585    2009  Yuniesky Betancourt  - - -   27  134  470  508  115   83
# 3681   9272    2018          Chris Davis    BAL   32  128  470  522   79   51
# 3678    620    2002          Neifi Perez    KCR   29  145  554  585  131  104
#
# ...

# %%
from pybaseball import statcast_batter_expected_stats, statcast_batter_percentile_ranks

#gets expected batting statistics from baseball savant
exp_stat = statcast_batter_expected_stats(2024)
exp_stat[exp_stat['pa'] > 502]
# Out:
#     last_name, first_name  player_id  year   pa  bip     ba  est_ba  \
# 0           Duran, Jarren     680776  2024  735  515  0.285   0.275
# 1          Ohtani, Shohei     660271  2024  731  479  0.310   0.314
# 2       Henderson, Gunnar     683002  2024  719  475  0.281   0.283
# 3          Semien, Marcus     543760  2024  718  546  0.237   0.251
# 4              Soto, Juan     665742  2024  713  461  0.288   0.316
# ..                    ...        ...   ...  ...  ...    ...     ...
# 124       Varsho, Daulton     662139  2024  513  324  0.214   0.186
# 125          Meyers, Jake     676694  2024  513  351  0.219   0.235
# 126           Ortiz, Joey     687401  2024  511  346  0.239   0.234
# 127         Winker, Jesse     608385  2024  508  329  0.253   0.245
# 128     Mountcastle, Ryan     663624  2024  507  365  0.271   0.272
#
#      est_ba_minus_ba_diff    slg  est_slg  est_slg_minus_slg_diff   woba  \
# 0                   0.010  0.492    0.453                   0.039  0.357
# ...

# %%
statcast_batter_percentile_ranks(2024)
# Out:
#                        player_name  player_id  year  xwoba   xba  xslg  xiso  \
# 0                     McCann, Kyle     668832  2024    NaN   NaN   NaN   NaN
# 1                    Outman, James     681546  2024    NaN   NaN   NaN   NaN
# 2                      Trout, Mike     545361  2024    NaN   NaN   NaN   NaN
# 3    Encarnacion-Strand, Christian     687952  2024    NaN   NaN   NaN   NaN
# 4                  Moreno, Gabriel     672515  2024   60.0  62.0  38.0  29.0
# ..                             ...        ...   ...    ...   ...   ...   ...
# 601                   Bichette, Bo     666182  2024    NaN   NaN   NaN   NaN
# 602                   Moore, Dylan     664238  2024   26.0   3.0   6.0  22.0
# 603               Robert Jr., Luis     673357  2024    6.0   6.0  25.0  47.0
# 604                 O'Neill, Tyler     641933  2024   76.0   8.0  90.0  97.0
# 605                Toglia, Michael     669911  2024   90.0  42.0  93.0  96.0
#
# ...

# %%
from pybaseball import statcast_batter_exitvelo_barrels

data = statcast_batter_exitvelo_barrels(2024)
data
# Out:
#       last_name, first_name  player_id  attempts  avg_hit_angle  \
# 0              Arraez, Luis     650333       611           13.7
# 1            Semien, Marcus     543760       546           17.0
# 2             Ramírez, José     608070       544           19.6
# 3           Witt Jr., Bobby     677951       538           15.1
# 4    Guerrero Jr., Vladimir     665489       524            7.4
# ..                      ...        ...       ...            ...
# 247           Gorman, Nolan     669357       216           20.3
# 248       Fitzgerald, Tyler     666149       207           20.2
# 249      Contreras, Willson     575929       205           14.2
# 250            Benson, Will     666181       192           18.2
# 251            Bauers, Jake     641343       184           22.6
#
#      anglesweetspotpercent  max_hit_speed  avg_hit_speed   ev50  fbld    gb  \
# 0                     40.9          108.4           86.3   94.8  89.3  83.9
# ...

# %%
from pybaseball import playerid_reverse_lookup

# a list of fangraphs ids
fg_ids = [826, 5417, 210, 1101]

# find their names and ids from other data sources
data = playerid_reverse_lookup(fg_ids, key_type='fangraphs')
data
# Out:
#   name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0   ramirez      manny     120903  ramim002  ramirma02            210
# 1     jeter      derek     116539  jeted001  jeterde01            826
# 2    suzuki     ichiro     400085  suzui001  suzukic01           1101
# 3    altuve       josé     514888  altuj001  altuvjo01           5417
#
#    mlb_played_first  mlb_played_last
# 0            1993.0           2011.0
# 1            1995.0           2014.0
# 2            2001.0           2019.0
# 3            2011.0           2024.0
